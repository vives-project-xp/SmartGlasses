# %%
# --- Imports ---
import os
import time
import numpy as np
import cv2
from matplotlib import pyplot as plt
import mediapipe as mp

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau

# --- Configuration ---
DATA_PATH = 'MP_Data'  # base path
actions = np.array(['hello', 'thanks', 'iloveyou'])
sequence_length = 30
no_sequences = 30
log_dir = 'Logs'
os.makedirs(log_dir, exist_ok=True)

# --- Label mapping ---
label_map = {label: idx for idx, label in enumerate(actions)}

# --- TensorBoard + Early stopping callbacks ---
tb_callback = TensorBoard(log_dir=log_dir)
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10)

# --- Load data ---
sequences, labels = [], []

for action in actions:
    action_path = os.path.join(DATA_PATH, action)
    if not os.path.exists(action_path):
        print(f"⚠️ Skipping missing folder: {action_path}")
        continue

    sequence_dirs = [d for d in os.listdir(action_path) if os.path.isdir(os.path.join(action_path, d))]
    if not sequence_dirs:
        print(f"⚠️ No sequences found for {action}")
        continue

    for sequence in sorted(sequence_dirs):
        seq_path = os.path.join(action_path, sequence)
        frames = []
        for frame_num in range(sequence_length):
            file_path = os.path.join(seq_path, f"{frame_num}.npy")
            if not os.path.exists(file_path):
                print(f"⚠️ Missing frame {frame_num} in {seq_path}, skipping this sequence.")
                frames = []  # discard incomplete sequence
                break
            frames.append(np.load(file_path))
        if frames:  # only add complete sequences
            sequences.append(frames)
            labels.append(label_map[action])

if not sequences or not labels:
    raise RuntimeError("❌ No valid training data found in MP_Data/. Check that folders and .npy files exist.")

X = np.array(sequences)
y = to_categorical(labels, num_classes=len(actions)).astype(int)
print(f"✅ Loaded {len(X)} sequences successfully.")


# --- Train/test split ---
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=True, random_state=42)

# Model Definition (Using Default Tanh for LSTM) ---
model = Sequential([
    # Remove 'activation=relu' to use the stable default (Tanh)
    LSTM(64, return_sequences=True, input_shape=(sequence_length, X.shape[2])), 
    Dropout(0.3),
    LSTM(128, return_sequences=True), 
    Dropout(0.3),
    LSTM(64), # Note: Tanh is fine for the final LSTM's main activation
    Dense(64, activation='relu'), # ReLU is fine here in the Dense layers
    Dense(32, activation='relu'),
    Dense(actions.shape[0], activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# --- Training ---
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,  # 2000 is overkill; use early stopping
    batch_size=16,
    callbacks=[tb_callback, early_stop, reduce_lr],
    verbose=1
)

# --- Evaluation ---
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Model accuracy: {acc:.4f}")

# --- Save model ---
model.save_weights('model_weights.weights.h5')  # CORRECTED: Must end in .weights.h5
model.save('model_fixed.keras')
print("Model saved successfully.")
# Out:
# ✅ Loaded 120 sequences successfully.
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - categorical_accuracy: 0.4474 - loss: 0.9892 - val_categorical_accuracy: 0.3333 - val_loss: 0.7978 - learning_rate: 0.0010
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - categorical_accuracy: 0.7456 - loss: 0.6657 - val_categorical_accuracy: 0.8333 - val_loss: 0.7915 - learning_rate: 0.0010
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - categorical_accuracy: 0.8684 - loss: 0.5012 - val_categorical_accuracy: 0.8333 - val_loss: 0.7540 - learning_rate: 0.0010
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - categorical_accuracy: 0.9035 - loss: 0.3207 - val_categorical_accuracy: 0.6667 - val_loss: 1.2031 - learning_rate: 0.0010
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - categorical_accuracy: 0.8333 - loss: 0.6562 - val_categorical_accuracy: 0.6667 - val_loss: 1.3686 - learning_rate: 0.0010
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - categorical_accuracy: 0.5702 - loss: 1.2724 - val_categorical_accuracy: 0.6667 - val_loss: 0.6717 - learning_rate: 0.0010
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - categorical_accuracy: 0.6053 - loss: 0.7615 - val_categorical_accuracy: 1.0000 - val_loss: 0.4053 - learning_rate: 0.0010
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - categorical_accuracy: 0.6140 - loss: 0.7140 - val_categorical_accuracy: 1.0000 - val_loss: 0.2973 - learning_rate: 0.0010
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - categorical_accuracy: 0.6228 - loss: 0.7188 - val_categorical_accuracy: 1.0000 - val_loss: 0.3200 - learning_rate: 0.0010
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - categorical_accuracy: 0.6491 - loss: 0.6815 - val_categorical_accuracy: 0.6667 - val_loss: 0.4100 - learning_rate: 0.0010
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - categorical_accuracy: 0.8947 - loss: 0.6225 - val_categorical_accuracy: 0.8333 - val_loss: 0.3222 - learning_rate: 0.0010
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - categorical_accuracy: 0.8596 - loss: 0.6423 - val_categorical_accuracy: 0.8333 - val_loss: 0.3607 - learning_rate: 0.0010
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - categorical_accuracy: 0.7632 - loss: 0.6092 - val_categorical_accuracy: 1.0000 - val_loss: 0.2336 - learning_rate: 0.0010
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - categorical_accuracy: 0.8333 - loss: 0.4868 - val_categorical_accuracy: 1.0000 - val_loss: 0.2576 - learning_rate: 0.0010
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - categorical_accuracy: 0.8070 - loss: 0.5486 - val_categorical_accuracy: 1.0000 - val_loss: 0.1878 - learning_rate: 0.0010
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - categorical_accuracy: 0.6930 - loss: 0.7688 - val_categorical_accuracy: 0.6667 - val_loss: 0.6807 - learning_rate: 0.0010
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - categorical_accuracy: 0.5877 - loss: 0.7944 - val_categorical_accuracy: 0.6667 - val_loss: 0.4471 - learning_rate: 0.0010
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - categorical_accuracy: 0.6491 - loss: 0.7216 - val_categorical_accuracy: 1.0000 - val_loss: 0.3494 - learning_rate: 0.0010
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - categorical_accuracy: 0.6228 - loss: 0.6992 - val_categorical_accuracy: 1.0000 - val_loss: 0.3313 - learning_rate: 0.0010
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - categorical_accuracy: 0.6316 - loss: 0.6993 - val_categorical_accuracy: 1.0000 - val_loss: 0.3134 - learning_rate: 0.0010
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - categorical_accuracy: 0.6404 - loss: 0.6758 - val_categorical_accuracy: 1.0000 - val_loss: 0.3329 - learning_rate: 0.0010
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - categorical_accuracy: 0.7544 - loss: 0.6730 - val_categorical_accuracy: 1.0000 - val_loss: 0.3788 - learning_rate: 0.0010
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - categorical_accuracy: 0.7807 - loss: 0.6519 - val_categorical_accuracy: 1.0000 - val_loss: 0.3940 - learning_rate: 0.0010
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - categorical_accuracy: 0.6404 - loss: 0.6425 - val_categorical_accuracy: 1.0000 - val_loss: 0.3075 - learning_rate: 0.0010
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - categorical_accuracy: 0.6316 - loss: 0.6156 - val_categorical_accuracy: 0.6667 - val_loss: 0.3964 - learning_rate: 0.0010
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - categorical_accuracy: 0.6053 - loss: 0.6709 - val_categorical_accuracy: 0.6667 - val_loss: 0.3495 - learning_rate: 5.0000e-04
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - categorical_accuracy: 0.6316 - loss: 0.6516 - val_categorical_accuracy: 1.0000 - val_loss: 0.2398 - learning_rate: 5.0000e-04
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - categorical_accuracy: 0.6491 - loss: 0.5853 - val_categorical_accuracy: 1.0000 - val_loss: 0.2350 - learning_rate: 5.0000e-04
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - categorical_accuracy: 0.8421 - loss: 0.5065 - val_categorical_accuracy: 1.0000 - val_loss: 0.1728 - learning_rate: 5.0000e-04
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - categorical_accuracy: 0.9211 - loss: 0.4282 - val_categorical_accuracy: 1.0000 - val_loss: 0.1530 - learning_rate: 5.0000e-04
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - categorical_accuracy: 0.8772 - loss: 0.4177 - val_categorical_accuracy: 0.8333 - val_loss: 0.3876 - learning_rate: 5.0000e-04
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - categorical_accuracy: 0.8421 - loss: 0.4850 - val_categorical_accuracy: 1.0000 - val_loss: 0.1390 - learning_rate: 5.0000e-04
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - categorical_accuracy: 0.7719 - loss: 0.5374 - val_categorical_accuracy: 0.6667 - val_loss: 0.6366 - learning_rate: 5.0000e-04
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - categorical_accuracy: 0.6140 - loss: 0.7308 - val_categorical_accuracy: 0.6667 - val_loss: 0.4749 - learning_rate: 5.0000e-04
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - categorical_accuracy: 0.6228 - loss: 0.6604 - val_categorical_accuracy: 1.0000 - val_loss: 0.3385 - learning_rate: 5.0000e-04
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - categorical_accuracy: 0.6579 - loss: 0.6473 - val_categorical_accuracy: 1.0000 - val_loss: 0.3480 - learning_rate: 5.0000e-04
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - categorical_accuracy: 0.6053 - loss: 0.6514 - val_categorical_accuracy: 0.8333 - val_loss: 0.3290 - learning_rate: 5.0000e-04
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - categorical_accuracy: 0.6930 - loss: 0.6373 - val_categorical_accuracy: 1.0000 - val_loss: 0.2636 - learning_rate: 5.0000e-04
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - categorical_accuracy: 0.6579 - loss: 0.6637 - val_categorical_accuracy: 1.0000 - val_loss: 0.3059 - learning_rate: 5.0000e-04
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - categorical_accuracy: 0.6404 - loss: 0.6560 - val_categorical_accuracy: 0.6667 - val_loss: 0.4312 - learning_rate: 5.0000e-04
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - categorical_accuracy: 0.6140 - loss: 0.6588 - val_categorical_accuracy: 0.6667 - val_loss: 0.3828 - learning_rate: 5.0000e-04
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - categorical_accuracy: 0.6140 - loss: 0.6403 - val_categorical_accuracy: 0.8333 - val_loss: 0.3536 - learning_rate: 5.0000e-04
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.7193 - loss: 0.6381 - val_categorical_accuracy: 1.0000 - val_loss: 0.3217 - learning_rate: 2.5000e-04
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - categorical_accuracy: 0.6491 - loss: 0.6321 - val_categorical_accuracy: 1.0000 - val_loss: 0.3113 - learning_rate: 2.5000e-04
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - categorical_accuracy: 0.6491 - loss: 0.6337 - val_categorical_accuracy: 1.0000 - val_loss: 0.3120 - learning_rate: 2.5000e-04
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - categorical_accuracy: 0.6579 - loss: 0.6202 - val_categorical_accuracy: 1.0000 - val_loss: 0.2891 - learning_rate: 2.5000e-04
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - categorical_accuracy: 0.6754 - loss: 0.6052 - val_categorical_accuracy: 1.0000 - val_loss: 0.3068 - learning_rate: 2.5000e-04
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - categorical_accuracy: 0.8772 - loss: 0.5543 - val_categorical_accuracy: 0.8333 - val_loss: 0.3337 - learning_rate: 2.5000e-04
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - categorical_accuracy: 0.7018 - loss: 0.6220 - val_categorical_accuracy: 0.6667 - val_loss: 0.4295 - learning_rate: 2.5000e-04
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - categorical_accuracy: 0.7807 - loss: 0.5477 - val_categorical_accuracy: 1.0000 - val_loss: 0.2622 - learning_rate: 2.5000e-04
# Model accuracy: 1.0000
# Model saved successfully.
